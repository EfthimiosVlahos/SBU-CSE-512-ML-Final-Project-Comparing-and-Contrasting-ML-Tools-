# %%
import pandas as pd
import numpy as np
import torch.nn as nn
from sklearn.model_selection import train_test_split
from numpy import loadtxt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
import math

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print ("Here1")

df = pd.read_csv("/content/drive/MyDrive/CSE 512 Project/ANN/normalized_numerical_data.csv")
df.head
X = df.drop(["gender"], axis=1)
y = np.array(df['gender'])
X.head
print(X.shape)
num_feat = X.shape[1]
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=400)

print ("Here2")

le = preprocessing.LabelEncoder()
le.fit(y_train)
y_train=le.transform(y_train)
y_train
X_test.reset_index()

print ("Here3")

def generateLayersNodes(n,input_nodes, output_nodes):
  layers = []
  change = (output_nodes-input_nodes)/ (n-1)
  nodes = input_nodes
  for i in range(1,n+1):
    layers.append(math.ceil(nodes))
    nodes+=change
  return layers

def createModel(n_layers,in_nodes,out_nodes, ac, lf,lr):
  model = Sequential()
  nodes_for_layers = generateLayersNodes(n_layers,in_nodes,out_nodes)
  for i in range(1,n_layers):
    if i == 1:
      model.add(Dense(in_nodes,input_shape = (7,),activation =ac ))
    else:
      model.add(Dense(nodes_for_layers[i-1],activation =ac ))
  model.add(Dense(1,activation=ac))
  model.compile(loss=lf,optimizer=tf.keras.optimizers.Adam(learning_rate=lr),metrics=['accuracy'])
  return model

def get_clf(meta, hidden_layer_sizes, dropout):
    n_features_in_ = meta["n_features_in_"]
    n_classes_ = meta["n_classes_"]
    model = keras.models.Sequential()
    model.add(keras.layers.Input(shape=(n_features_in_,)))
    for hidden_layer_size in hidden_layer_sizes:
        model.add(keras.layers.Dense(hidden_layer_size, activation="relu"))
        model.add(keras.layers.Dropout(dropout))
    model.add(keras.layers.Dense(1, activation="sigmoid"))
    return model

clf = KerasClassifier(
    model=get_clf,
    loss="binary_crossentropy",
    optimizer="adam",
    optimizer__lr=0.1,
    model__hidden_layer_sizes=(100,),
    model__dropout=0.5,
    verbose=False,
)

params = {
    'optimizer__lr': [0.05, 0.1],
    'model__hidden_layer_sizes': [(100, ), (50, 50, )],
    'model__dropout': [0, 0.5],
}

gs = GridSearchCV(clf, params, scoring='accuracy', n_jobs=-1, verbose=True)

print ("Here4")

gs.fit(X_train, y_train)

print ("Here5")

print(gs.best_score_, gs.best_params_)

f = open("ann_params.txt", "w")
f.write("Best Score : "+str(gs.best_score_))
f.write(str(gs.best_params_))
f.close()

print ("Here6")
# Out:
# /content/drive/MyDrive/CSE512 ML Project

# %%
# Out:
# sample_data/

# %%
# Out:
# <bound method NDFrame.head of       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1               11.8                 6.1          1          0
# 1             0               14.0                 5.4          0          0
# 2             0               11.8                 6.3          1          1
# 3             0               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# ...         ...                ...                 ...        ...        ...
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
# ...

# %%
# Out:
# <bound method NDFrame.head of       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1               11.8                 6.1          1          0
# 1             0               14.0                 5.4          0          0
# 2             0               11.8                 6.3          1          1
# 3             0               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# ...         ...                ...                 ...        ...        ...
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
# ...

# %%
# Out:
# (5001, 7)

# %%
# Out:
# array([1, 0, 0, ..., 0, 0, 0])

# %%
# Out:
#       index  long_hair  forehead_width_cm  forehead_height_cm  nose_wide  \
# 0      1501          1               13.2                 5.7          1
# 1      2586          1               13.7                 6.0          0
# 2      2653          0               12.9                 5.3          0
# 3      1055          1               13.2                 5.9          1
# 4       705          0               15.2                 5.6          1
# ...     ...        ...                ...                 ...        ...
# 996    2313          1               13.5                 5.8          0
# 997    3214          1               12.6                 5.5          1
# 998    2732          1               14.3                 5.7          0
# 999    1926          1               13.9                 6.3          1
# 1000   4227          1               13.0                 5.4          0
#
#       nose_long  lips_thin  distance_nose_to_lip_long
# ...

# %% [markdown]
# GridSearch [LINK](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html)
# <br>
# SVM [LINK](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html)

# %%
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid=[{'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001],
#                           'kernel': ['sigmoid']}])

# %%
# Out:
# ['mean_fit_time',
#  'mean_score_time',
#  'mean_test_score',
#  'param_C',
#  'param_gamma',
#  'param_kernel',
#  'params',
#  'rank_test_score',
#  'split0_test_score',
#  'split1_test_score',
#  'split2_test_score',
#  'split3_test_score',
#  'split4_test_score',
#  'std_fit_time',
#  'std_score_time',
#  'std_test_score']

# %%
# Out:
# Train Accuracy of Polynomial SVM is :  96.625 %
# Test Accuracy of Polynomial SVM is :  96.40359640359641 %

# %%
# Out:
# Train Accuracy of RBF SVM is :  97.275 %
# Test Accuracy of RBF SVM is :  96.8031968031968 %

# %%
# Out:
# Train Accuracy of Sigmoid SVM is :  96.675 %
# Test Accuracy of Sigmoid SVM is :  96.2037962037962 %

# %%
# Out:
# There are  12  False Negatives
# ...
# Features :  long_hair                     0.0
# forehead_width_cm            11.8
# forehead_height_cm            6.5
# nose_wide                     1.0
# nose_long                     0.0
# lips_thin                     1.0
# distance_nose_to_lip_long     1.0
# Name: 106, dtype: float64
# Prediction :  Male
# True Label :  Female
# ...
# Features :  long_hair                     1.0
# forehead_width_cm            11.9
# forehead_height_cm            5.4
# nose_wide                     1.0
# nose_long                     0.0
# lips_thin                     1.0
# distance_nose_to_lip_long     1.0
# Name: 8, dtype: float64
# Prediction :  Male
# True Label :  Female
# ...
# Features :  long_hair                     1.0
# forehead_width_cm            13.0
# forehead_height_cm            5.5
# nose_wide                     1.0
# nose_long                     1.0
# lips_thin                     0.0
# distance_nose_to_lip_long     1.0
# Name: 472, dtype: float64
# ...

# %%
print("There are ",len(FP)," False Positives")
for fp in FP:
  print("========================")
  print("Features : ",fp[0])
  print("Prediction : ",fp[1])
  print("True Label : ",fp[2])
# Out:
# There are  20  False Positives
# ...
# Features :  long_hair                     1.0
# forehead_width_cm            13.2
# forehead_height_cm            5.4
# nose_wide                     0.0
# nose_long                     1.0
# lips_thin                     1.0
# distance_nose_to_lip_long     0.0
# Name: 3899, dtype: float64
# Prediction :  Female
# True Label :  Male
# ...
# Features :  long_hair                     1.0
# forehead_width_cm            11.5
# forehead_height_cm            6.2
# nose_wide                     1.0
# nose_long                     1.0
# lips_thin                     0.0
# distance_nose_to_lip_long     0.0
# Name: 633, dtype: float64
# Prediction :  Female
# True Label :  Male
# ...
# Features :  long_hair                     1.0
# forehead_width_cm            11.9
# forehead_height_cm            6.2
# nose_wide                     0.0
# nose_long                     0.0
# lips_thin                     1.0
# distance_nose_to_lip_long     1.0
# Name: 2642, dtype: float64
# ...

# %% [markdown]
# Random Forest [LINK](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html)

# %%
# Out:
# RandomForestClassifier(max_depth=3, random_state=0)

# %%
# Out:
# Accuracy of Random Forest is :  96.00399600399601 %

# %%
# Out:
# There are  20  False Negatives
# ...
# Features :  long_hair                     0.0
# forehead_width_cm            11.8
# forehead_height_cm            6.5
# nose_wide                     1.0
# nose_long                     0.0
# lips_thin                     1.0
# distance_nose_to_lip_long     1.0
# Name: 106, dtype: float64
# Prediction :  Male
# True Label :  Female
# ...
# Features :  long_hair                     1.0
# forehead_width_cm            11.9
# forehead_height_cm            6.3
# nose_wide                     0.0
# nose_long                     1.0
# lips_thin                     0.0
# distance_nose_to_lip_long     1.0
# Name: 4616, dtype: float64
# Prediction :  Male
# True Label :  Female
# ...
# Features :  long_hair                     1.0
# forehead_width_cm            11.9
# forehead_height_cm            5.4
# nose_wide                     1.0
# nose_long                     0.0
# lips_thin                     1.0
# distance_nose_to_lip_long     1.0
# Name: 8, dtype: float64
# ...

# %%
# Out:
# There are  20  False Positives
# ...
# Features :  long_hair                     1.0
# forehead_width_cm            13.2
# forehead_height_cm            5.4
# nose_wide                     0.0
# nose_long                     1.0
# lips_thin                     1.0
# distance_nose_to_lip_long     0.0
# Name: 3899, dtype: float64
# Prediction :  Female
# True Label :  Male
# ...
# Features :  long_hair                     1.0
# forehead_width_cm            14.1
# forehead_height_cm            6.3
# nose_wide                     0.0
# nose_long                     1.0
# lips_thin                     1.0
# distance_nose_to_lip_long     0.0
# Name: 4593, dtype: float64
# Prediction :  Female
# True Label :  Male
# ...
# Features :  long_hair                     1.0
# forehead_width_cm            11.9
# forehead_height_cm            6.2
# nose_wide                     0.0
# nose_long                     0.0
# lips_thin                     1.0
# distance_nose_to_lip_long     1.0
# Name: 2642, dtype: float64
# ...

# %% [markdown]
# Hyper Parameter Search for ANN<br>
# Reference : [LINK](https://datagraphi.com/blog/post/2019/12/17/how-to-find-the-optimum-number-of-hidden-layers-and-nodes-in-a-neural-network-model)

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   """Entry point for launching an IPython kernel.

# %%
# Out:
# Epoch 1/150
# 400/400 [==============================] - 2s 2ms/step - loss: 0.6001 - accuracy: 0.7520
# Epoch 2/150
# 400/400 [==============================] - 1s 2ms/step - loss: 0.2027 - accuracy: 0.9530
# Epoch 3/150
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1112 - accuracy: 0.9545
# Epoch 4/150
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0992 - accuracy: 0.9548
# Epoch 5/150
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0961 - accuracy: 0.9545
# Epoch 6/150
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0962 - accuracy: 0.9532
# Epoch 7/150
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0942 - accuracy: 0.9505
# Epoch 8/150
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0945 - accuracy: 0.9528
# Epoch 9/150
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0941 - accuracy: 0.9523
# Epoch 10/150
# ...

# %%
_,accuracy = model.evaluate(X_test,le.transform(y_test))
print('Accuracy : %.2f' % (accuracy*100))
# Out:
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0862 - accuracy: 0.9620
# Accuracy : 96.20

# %%
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 2.5 MB 16.3 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for mpi4py: filename=mpi4py-3.1.4-cp37-cp37m-linux_x86_64.whl size=2185750 sha256=0afce766707ce69d708342cccf8ee93037f760750196b96b38093afadcfc5370
#   Stored in directory: /root/.cache/pip/wheels/99/54/29/187b5768bbb7beeab6753bc30acf56f35bc8ca9c214a31e173
# Successfully built mpi4py
# ...
